# %% [markdown]
# # WEATHER TASK

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\simon\Desktop\Data Analysis Projects\Python tasks - Weather; Udemy; London Housing\Datasets\Weather data.csv")
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
#1. FIND ALL THE UNIQUE 'wind speed' VALUES

df['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
#2. FIND THE NUMBER OF TIMES WHEN THE 'weather is exactly Clear'

df.Weather
# Out:
# 0                        Fog
# 1                        Fog
# 2       Freezing Drizzle,Fog
# 3       Freezing Drizzle,Fog
# 4                        Fog
#                 ...
# 8779                    Snow
# 8780                    Snow
# 8781                    Snow
# 8782                    Snow
# 8783                    Snow
# Name: Weather, Length: 8784, dtype: object

# %%
df ['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
df.head(20)
# Out:
#          Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0    1/1/2012 0:00    -1.8              -3.9         86                4
# 1    1/1/2012 1:00    -1.8              -3.7         87                4
# 2    1/1/2012 2:00    -1.8              -3.4         89                7
# 3    1/1/2012 3:00    -1.5              -3.2         88                6
# 4    1/1/2012 4:00    -1.5              -3.3         88                7
# 5    1/1/2012 5:00    -1.4              -3.3         87                9
# 6    1/1/2012 6:00    -1.5              -3.1         89                7
# 7    1/1/2012 7:00    -1.4              -3.6         85                7
# 8    1/1/2012 8:00    -1.4              -3.6         85                9
# 9    1/1/2012 9:00    -1.3              -3.1         88               15
# 10  1/1/2012 10:00    -1.0              -2.3         91                9
# 11  1/1/2012 11:00    -0.5              -2.1         89                7
# ...

# %%
df['Weather']=='Clear'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather, Length: 8784, dtype: bool

# %%
df[df['Weather']=='Clear'].shape
# Out:
# (1326, 8)

# %%
no_of_clear = df[df['Weather']=='Clear'].shape[0]
no_of_clear
# Out:
# 1326

# %%
df['Weather']!='Clear'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 8779    True
# 8780    True
# 8781    True
# 8782    True
# 8783    True
# Name: Weather, Length: 8784, dtype: bool

# %%
#3. FIND THE NUMBER OF TUMES WHEN THE the 'Wind Speed was exactly 4km/h'

df['Wind Speed_km/h']==4
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Wind Speed_km/h, Length: 8784, dtype: bool

# %%
df[df['Wind Speed_km/h']==4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
# Alternatively:
df[df['Wind Speed_km/h']==4]['Wind Speed_km/h'].count()
# Out:
# 474

# %%
#4. RENAME 'Weather' column to 'Weather Condition'

df.rename(columns = {'Weather': 'Weather Condition'}, inplace = True)

#4.5. RENAME 'Press_kPa' to 'Pressure_kPa'
df.rename(columns = {'Press_kPa': 'Pressure_kPa'}, inplace = True)

df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_% Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86              24
# 1        1/1/2012 1:00    -1.8              -3.7         87              24
# 2        1/1/2012 2:00    -1.8              -3.4         89              24
# 3        1/1/2012 3:00    -1.5              -3.2         88              24
# 4        1/1/2012 4:00    -1.5              -3.3         88              24
# ...                ...     ...               ...        ...             ...
# 8779  12/31/2012 19:00     0.1              -2.7         81              24
# 8780  12/31/2012 20:00     0.2              -2.4         83              24
# 8781  12/31/2012 21:00    -0.5              -1.5         93              24
# 8782  12/31/2012 22:00    -0.2              -1.8         89              24
# 8783  12/31/2012 23:00     0.0              -2.1         86              24
#
# ...
